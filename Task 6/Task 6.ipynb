# %% [markdown]
# <b><u>Task-6:</u></b><br>
# Develop Logistic Regression model for a given dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("tips.csv")
print("Rows and Columns are:",data.shape)
data.head(10)
# Out:
# Rows and Columns are: (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_fare=data[['tip']].values
y=data['sex'].values
lr=LogisticRegression()

# %%
print("Fit is:",lr.fit(x_fare,y))
y_predict=lr.predict(x_fare)
print("Score is:",lr.score(x_fare,y))
plt.plot(x_fare,y,color='navy',label='Regression Line')
plt.scatter(x_fare,y,color='darkorange',label='Scatter Plot')
plt.xlabel('tip')
plt.ylabel('sex')
plt.legend()
plt.show()
# Out:
# Fit is: LogisticRegression()
# Score is: 0.6434426229508197
